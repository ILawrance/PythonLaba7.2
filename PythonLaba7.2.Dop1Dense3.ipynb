# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2023-06-02 09:19:26.440688: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-02 09:19:28.032150: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-02 09:19:28.036366: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-02 09:19:33.492384: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2.12.0

# %%
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat','Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# ИЗУЧЕНИЕ ДАННЫХ

train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
# ПОДГОТОВКА ДАННЫХ

plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
train_images = train_images/255.0
test_images = test_images/255.0

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
# ПОСТРОЕНИЕ МОДЕЛИ

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
    ])


# КОМПИЛЯЦИЯ МОДЕЛИ
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
 
# ВЫДЕЛЕНИЕ ПРОВЕРОЧНОГО НАБОРА
x_val = train_images[:10000]
partial_x_train = train_images[10000:]
y_val = train_labels[:10000]
partial_y_train = train_labels[10000:]

# ОБУЧЕНИЕ МОДЕЛИ
history = model.fit(partial_x_train,
partial_y_train,
epochs=20,
batch_size=512,
validation_data=(x_val, y_val))
# Out:
# 2023-06-02 09:19:50.806058: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 156800000 exceeds 10% of free system memory.
# Epoch 1/20
# 95/98 [============================>.] - ETA: 0s - loss: 0.7450 - accuracy: 0.7475
# 2023-06-02 09:19:59.845179: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 31360000 exceeds 10% of free system memory.
# 98/98 [==============================] - 6s 19ms/step - loss: 0.7389 - accuracy: 0.7492 - val_loss: 0.4831 - val_accuracy: 0.8272
# Epoch 2/20
# 98/98 [==============================] - 1s 14ms/step - loss: 0.4464 - accuracy: 0.8411 - val_loss: 0.4117 - val_accuracy: 0.8537
# Epoch 3/20
# 98/98 [==============================] - 1s 14ms/step - loss: 0.3987 - accuracy: 0.8562 - val_loss: 0.3952 - val_accuracy: 0.8585
# Epoch 4/20
# 98/98 [==============================] - 1s 11ms/step - loss: 0.3712 - accuracy: 0.8661 - val_loss: 0.3717 - val_accuracy: 0.8660
# Epoch 5/20
# 98/98 [==============================] - 1s 13ms/step - loss: 0.3455 - accuracy: 0.8750 - val_loss: 0.3559 - val_accuracy: 0.8738
# Epoch 6/20
# 98/98 [==============================] - 1s 12ms/step - loss: 0.3269 - accuracy: 0.8825 - val_loss: 0.3468 - val_accuracy: 0.8747
# Epoch 7/20
# 98/98 [==============================] - 1s 10ms/step - loss: 0.3131 - accuracy: 0.8854 - val_loss: 0.3373 - val_accuracy: 0.8799
# Epoch 8/20
# 98/98 [==============================] - 2s 16ms/step - loss: 0.2945 - accuracy: 0.8920 - val_loss: 0.3244 - val_accuracy: 0.8828
# Epoch 9/20
# 98/98 [==============================] - 2s 15ms/step - loss: 0.2857 - accuracy: 0.8948 - val_loss: 0.3200 - val_accuracy: 0.8803
# Epoch 10/20
# 98/98 [==============================] - 1s 15ms/step - loss: 0.2715 - accuracy: 0.9002 - val_loss: 0.3192 - val_accuracy: 0.8826
# Epoch 11/20
# 98/98 [==============================] - 2s 17ms/step - loss: 0.2642 - accuracy: 0.9037 - val_loss: 0.3037 - val_accuracy: 0.8900
# Epoch 12/20
# 98/98 [==============================] - 1s 14ms/step - loss: 0.2518 - accuracy: 0.9072 - val_loss: 0.3184 - val_accuracy: 0.8834
# Epoch 13/20
# 98/98 [==============================] - 2s 17ms/step - loss: 0.2448 - accuracy: 0.9099 - val_loss: 0.3084 - val_accuracy: 0.8889
# Epoch 14/20
# 98/98 [==============================] - 2s 16ms/step - loss: 0.2397 - accuracy: 0.9124 - val_loss: 0.3051 - val_accuracy: 0.8890
# Epoch 15/20
# 98/98 [==============================] - 2s 16ms/step - loss: 0.2306 - accuracy: 0.9144 - val_loss: 0.3102 - val_accuracy: 0.8873
# Epoch 16/20
# 98/98 [==============================] - 1s 15ms/step - loss: 0.2260 - accuracy: 0.9164 - val_loss: 0.3083 - val_accuracy: 0.8890
# Epoch 17/20
# 98/98 [==============================] - 1s 15ms/step - loss: 0.2174 - accuracy: 0.9196 - val_loss: 0.3011 - val_accuracy: 0.8907
# Epoch 18/20
# 98/98 [==============================] - 1s 14ms/step - loss: 0.2177 - accuracy: 0.9199 - val_loss: 0.2989 - val_accuracy: 0.8935
# Epoch 19/20
# 98/98 [==============================] - 1s 15ms/step - loss: 0.2039 - accuracy: 0.9252 - val_loss: 0.2957 - val_accuracy: 0.8937
# Epoch 20/20
# 98/98 [==============================] - 2s 15ms/step - loss: 0.2026 - accuracy: 0.9248 - val_loss: 0.3061 - val_accuracy: 0.8911

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'bo', label='Потери на этапе обучения')
plt.plot(epochs, val_loss, 'b', label=' Потери на этапе проверки')
plt.title('Потери при обучении и проверки')
plt.xlabel('Эпохи')
plt.ylabel('Потери')
plt.legend()
plt.show()

# %%
plt.clf()
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'bo', label='Точность на этапе обучения')
plt.plot(epochs, val_acc, 'b', label=' Точность на этапе проверки')
plt.title('Точность при обучении и проверки')
plt.xlabel('Эпохи')
plt.ylabel('Точность')
plt.legend()
plt.show()

# %%
#  ОЦЕНКА ТОЧНОСТИ МОДЕЛИ 
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('\nТочность на проверочных данных:', test_acc)
# Out:
#  49/313 [===>..........................] - ETA: 0s - loss: 0.3046 - accuracy: 0.8929
# 2023-06-02 09:20:38.399270: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 31360000 exceeds 10% of free system memory.
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3357 - accuracy: 0.8836
#
# Точность на проверочных данных: 0.8835999965667725

# %%
# ИСПОЛЬЗОВАНИЕ МОДЕЛИ ДЛЯ ПРЕДСКАЗАНИЙ

predictions = model.predict(test_images)
predictions[0]
# Out:
#   1/313 [..............................] - ETA: 32s
# 2023-06-02 09:20:39.286074: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 31360000 exceeds 10% of free system memory.
# 313/313 [==============================] - 1s 2ms/step
# array([6.5597909e-08, 3.6821680e-07, 3.9451091e-08, 3.9300211e-08,
#        1.8040551e-07, 1.0110751e-04, 6.2313514e-09, 6.7916992e-03,
#        2.2082497e-06, 9.9310434e-01], dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 9

# %%
test_labels[0]
# Out:
# 9

# %%
# График изображений 
def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img, cmap=plt.cm.binary)
    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'
    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label], 
                                        100*np.max(predictions_array),
                                        class_names[true_label]),
                                        color=color)

# Диаграмма вероятностей классов
def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array[i], true_label[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions, test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions, test_labels)
plt.show()

# %%
i = 12
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions, test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions,test_labels)
plt.show()

# %%
# Отображаем первые X тестовых изображений, их предсказанную и настоящую метки.
# Корректные предсказания окрашиваем в синий цвет, ошибочные в красный.
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2*num_cols, 2*i+1)
    plot_image(i, predictions, test_labels, test_images)
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i, predictions, test_labels)
    plt.show()

# %%
# Берем одну картинку из проверочного сета.
img = test_images[0]
print(img.shape)
# Out:
# (28, 28)

# %%
# Добавляем изображение в пакет данных, состоящий только из одного элемента.
img = (np.expand_dims(img,0))
print(img.shape)
# Out:
# (1, 28, 28)

# %%
predictions_single = model.predict(img)
print(predictions_single)
# Out:
# 1/1 [==============================] - 0s 30ms/step
# [[6.5598016e-08 3.6821712e-07 3.9451162e-08 3.9300204e-08 1.8040583e-07
#   1.0110768e-04 6.2313501e-09 6.7917109e-03 2.2082493e-06 9.9310416e-01]]

# %%
plot_value_array(0, predictions_single, test_labels)
_ = plt.xticks(range(10), class_names, rotation=45)

# %%
np.argmax(predictions_single[0])
# Out:
# 9

# %%
model.save('model_Dop1_3dense_class.h5')

baza_model = keras.models.load_model('model_baza_class.h5')
loss, acc = baza_model.evaluate(test_images, test_labels)
print("Базовая модель, точность: {:5.2f}%".format(100*acc))
print("Базовая модель, потери: {:5.2f}%".format(100*loss))

Dense3_model =  keras.models.load_model('model_Dop1_3dense_class.h5')
test_loss, test_acc = Dense3_model.evaluate(test_images, test_labels)
print("Модель с 3 скрытыми слоями, точность: {:5.2f}%".format(100*test_acc))
print("Модель с 3 скрытыми слоями, потери: {:5.2f}%".format(100*test_loss))
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3401 - accuracy: 0.8777
# Базовая модель, точность: 87.77%
# Базовая модель, потери: 34.01%
# 313/313 [==============================] - 2s 5ms/step - loss: 0.3357 - accuracy: 0.8836
# Модель с 3 скрытыми слоями, точность: 88.36%
# Модель с 3 скрытыми слоями, потери: 33.57%
